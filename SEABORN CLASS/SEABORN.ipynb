# %%
import numpy as np
import pandas as pd
import seaborn as sms
import matplotlib.pyplot as plt

# %%
new = pd.read_csv(r"C:\Users\HP\Desktop\student.csv")
new
# Out:
#      gender ethnicity  parental_education         lunch  \
# 0    female   group B   bachelor's degree      standard
# 1    female   group C        some college      standard
# 2    female   group B     master's degree      standard
# 3      male   group A  associate's degree  free/reduced
# 4      male   group C        some college      standard
# ..      ...       ...                 ...           ...
# 995  female   group E     master's degree      standard
# 996    male   group C         high school  free/reduced
# 997  female   group C         high school  free/reduced
# 998  female   group D        some college      standard
# 999  female   group D        some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# ...

# %%
new.head()
# Out:
#    gender ethnicity  parental_education         lunch test_preparation_course  \
# 0  female   group B   bachelor's degree      standard                    none
# 1  female   group C        some college      standard               completed
# 2  female   group B     master's degree      standard                    none
# 3    male   group A  associate's degree  free/reduced                    none
# 4    male   group C        some college      standard                    none
#
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
new.tail()
# Out:
#      gender ethnicity parental_education         lunch  \
# 995  female   group E    master's degree      standard
# 996    male   group C        high school  free/reduced
# 997  female   group C        high school  free/reduced
# 998  female   group D       some college      standard
# 999  female   group D       some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
len(new)
# Out:
# 1000

# %% [markdown]
# # countplot

# %%
sms.countplot(data = new, x = 'gender')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
new['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
sms.countplot(data = new, x = 'ethnicity')
# Out:
# <Axes: xlabel='ethnicity', ylabel='count'>

# %%
sms.countplot(data = new, x = 'parental_education')
plt.xticks(rotation = 15)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, "bachelor's degree"),
#   Text(1, 0, 'some college'),
#   Text(2, 0, "master's degree"),
#   Text(3, 0, "associate's degree"),
#   Text(4, 0, 'high school'),
#   Text(5, 0, 'some high school')])

# %%
plt.bar(data = new, x = 'gender', height = 3)
plt.show()

# %%
# new.plot(kind = 'pie', title = 'new')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 new.plot(kind = 'pie', title = 'new')
#       2 plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:926, in PlotAccessor.__call__(self, *args, **kwargs)
#     924 if isinstance(data, ABCDataFrame):
#     925     if y is None and kwargs.get("subplots") is False:
# --> 926         raise ValueError(
#     927             f"{kind} requires either y column or 'subplots=True'"
#     928         )
#     929     if y is not None:
#     930         if is_integer(y) and not data.columns._holds_integer():
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
y = new['gender'].value_counts().index.tolist()

# %%
y
# Out:
# ['female', 'male']

# %%
x = new['gender'].value_counts().tolist()

# %%
x
# Out:
# [518, 482]

# %%
j = plt.figure(figsize = (2,2))
plt.pie(x,labels = y)
# Out:
# ([<matplotlib.patches.Wedge at 0x2ab23db3c10>,
# ...
#  [Text(-0.06217041096298424, 1.0982417038160106, 'female'),
#   Text(0.06217041096298411, -1.0982417038160106, 'male')])

# %%
j = plt.figure(figsize = (2,2))
plt.pie(x,labels = y, autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2ab23e45450>,
# ...
#  [Text(-0.06217041096298424, 1.0982417038160106, 'female'),
#   Text(0.06217041096298411, -1.0982417038160106, 'male')],
#  [Text(-0.033911133252536856, 0.5990409293541875, '51.80%'),
#   Text(0.033911133252536786, -0.5990409293541875, '48.20%')])

# %%
j = plt.figure(figsize = (2,2))
plt.pie(x,labels = y, autopct='%.2f%%',pctdistance=1.4)
# Out:
# ([<matplotlib.patches.Wedge at 0x2ab23e8b7d0>,
# ...
#  [Text(-0.06217041096298424, 1.0982417038160106, 'female'),
#   Text(0.06217041096298411, -1.0982417038160106, 'male')],
#  [Text(-0.07912597758925266, 1.397762168493104, '51.80%'),
#   Text(0.0791259775892525, -1.397762168493104, '48.20%')])

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
new.head()
# Out:
#    gender ethnicity  parental_education         lunch test_preparation_course  \
# 0  female   group B   bachelor's degree      standard                    none
# 1  female   group C        some college      standard               completed
# 2  female   group B     master's degree      standard                    none
# 3    male   group A  associate's degree  free/reduced                    none
# 4    male   group C        some college      standard                    none
#
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
sms.catplot(data = new, x = 'lunch', y = 'math_score', kind = 'box')
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sms.scatterplot(data = new, x = 'math_score', y = 'reading_score')
# Out:
# <Axes: xlabel='math_score', ylabel='reading_score'>

# %%
sms.scatterplot(data = new, x = 'math_score', y = 'reading_score', hue = 'gender')
# Out:
# <Axes: xlabel='math_score', ylabel='reading_score'>

# %%
sms.catplot(data = new, x = 'ethnicity', y = 'math_score', kind = 'box')
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sms.histplot(data = new, x ='math_score' )
# Out:
# <Axes: xlabel='math_score', ylabel='Count'>

# %%
sms.histplot(data = new, x ='math_score', kde = True )
# Out:
# <Axes: xlabel='math_score', ylabel='Count'>

# %%
sms.histplot(data = new, x ='math_score', kde = True, hue = 'gender')
# Out:
# <Axes: xlabel='math_score', ylabel='Count'>

# %%
sms.histplot(data = new, x ='math_score', kde = True, hue = 'gender', palette = ['green','red'] )
# Out:
# <Axes: xlabel='math_score', ylabel='Count'>

# %%
sms.kdeplot(data = new, x = 'math_score', hue = 'ethnicity')
# Out:
# <Axes: xlabel='math_score', ylabel='Density'>

# %%
sms.kdeplot(data = new, x = 'math_score', hue = 'ethnicity', common_norm=False)
# Out:
# <Axes: xlabel='math_score', ylabel='Density'>

# %%
sms.scatterplot(data = new, x = 'math_score', y = 'reading_score', hue = 'gender', palette=['green','hotpink'])
# Out:
# <Axes: xlabel='math_score', ylabel='reading_score'>
